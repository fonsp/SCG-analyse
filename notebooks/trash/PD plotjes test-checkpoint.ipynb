# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = [12, 6]

# %%
data_path = "../../data/origineel"

if not Path(data_path).is_dir():
    raise Warning("Data path does not exist")

# %%
# Lijst van .csv-bestanden
data_file_paths = [p for p in Path(data_path).iterdir() if p.suffix==".csv"]

# %%
# Lees de drie bestanden van het circuit as pandas DataFrame
cableconfig = pd.read_csv(data_file_paths[3], sep=";")
partialdischarges = pd.read_csv(data_file_paths[4], sep=";")
warning = pd.read_csv(data_file_paths[5], sep=";")

# %% [markdown]
# ## PD plotjes

# %%
partialdischarges
# Out:
#             Date/time (UTC)  Location in meters (m)  Charge (picocoulomb)
# 0       2017-08-21 14:39:00                     NaN                   NaN
# 1       2017-08-21 14:40:00                     NaN                   NaN
# 2       2017-08-21 14:41:00                     NaN                   NaN
# 3       2017-08-21 14:42:00                     NaN                   NaN
# 4       2017-08-21 14:43:00                     NaN                   NaN
# 5       2017-08-21 14:44:00                     NaN                   NaN
# 6       2017-08-21 14:45:00                     NaN                   NaN
# 7       2017-08-21 14:46:00                     NaN                   NaN
# 8       2017-08-21 14:47:00                     NaN                   NaN
# 9       2017-08-21 14:48:00                     NaN                   NaN
# 10      2017-08-21 14:49:00                     NaN                   NaN
# 11      2017-08-21 14:50:00                     NaN                   NaN
# 12      2017-08-21 14:51:00                     NaN                   NaN
# 13      2017-08-21 14:52:00                     NaN                   NaN
# 14      2017-08-21 14:53:00                     NaN                   NaN
# 15      2017-08-21 14:54:00                     NaN                   NaN
# 16      2017-08-21 14:55:00                     NaN                   NaN
# 17      2017-08-21 14:56:00                     NaN                   NaN
# 18      2017-08-21 14:57:00                     NaN                   NaN
# 19      2017-08-21 14:58:00                     NaN                   NaN
# 20      2017-08-21 14:59:00                     NaN                   NaN
# 21      2017-08-21 15:00:00                     NaN                   NaN
# 22      2017-08-21 15:01:00                     NaN                   NaN
# 23      2017-08-21 15:02:00                     NaN                   NaN
# 24      2017-08-21 15:03:00                     NaN                   NaN
# 25      2017-08-21 15:04:00                     NaN                   NaN
# 26      2017-08-21 15:05:00                     NaN                   NaN
# 27      2017-08-21 15:06:00                     NaN                   NaN
# 28      2017-08-21 15:07:00                     NaN                   NaN
# 29      2017-08-21 15:08:00                     NaN                   NaN
# ...                     ...                     ...                   ...
# 368981  2018-11-13 10:35:00                     NaN                   NaN
# 368982  2018-11-13 11:00:00                     NaN                   NaN
# 368983  2018-11-13 11:01:00                     NaN                   NaN
# 368984  2018-11-13 11:02:00                     NaN                   NaN
# 368985  2018-11-13 11:03:00                     NaN                   NaN
# 368986  2018-11-13 11:04:00                     NaN                   NaN
# 368987  2018-11-13 11:05:00                     NaN                   NaN
# 368988  2018-11-13 11:06:00                     NaN                   NaN
# 368989  2018-11-13 11:07:00                     NaN                   NaN
# 368990  2018-11-13 11:08:00                     NaN                   NaN
# 368991  2018-11-13 11:09:00                     NaN                   NaN
# 368992  2018-11-13 11:10:00                     NaN                   NaN
# 368993  2018-11-13 11:11:00                     NaN                   NaN
# 368994  2018-11-13 11:12:00                     NaN                   NaN
# 368995  2018-11-13 11:13:00                     NaN                   NaN
# 368996  2018-11-13 11:14:00                     NaN                   NaN
# 368997  2018-11-13 11:15:00                     NaN                   NaN
# 368998  2018-11-13 11:16:00                     NaN                   NaN
# 368999  2018-11-13 11:17:00                     NaN                   NaN
# 369000  2018-11-13 11:18:00                     NaN                   NaN
# 369001  2018-11-13 11:19:00                     NaN                   NaN
# 369002  2018-11-13 11:20:00                     NaN                   NaN
# 369003  2018-11-13 11:21:00                     NaN                   NaN
# 369004  2018-11-13 11:22:00                     NaN                   NaN
# 369005  2018-11-13 11:23:00                     NaN                   NaN
# 369006  2018-11-13 11:24:00                     NaN                   NaN
# 369007  2018-11-13 11:25:00                     NaN                   NaN
# 369008  2018-11-13 11:26:00                     NaN                   NaN
# 369009  2018-11-13 11:27:00                     NaN                   NaN
# 369010  2018-11-13 11:28:00                     NaN                   NaN
#
# [369011 rows x 3 columns]

# %%
# Namen van de kolommen
time_col, location_col, charge_col = partialdischarges.columns

# Check that each row either has location and charge undefinied, or both defined:
for i in np.arange(len(partialdischarges))[np.isnan(partialdischarges[location_col]) != np.isnan(partialdischarges[charge_col])]:
    raise Warning(f"Row {i} has missing values")

# Lijst met bools die aangeeft of er op dat tijdstip een PD was
pd_occured = ~np.isnan(partialdischarges[location_col])

# De drie kolommen; alleen op tijdstippen met PD
locations = partialdischarges[location_col][pd_occured]
charges = partialdischarges[charge_col][pd_occured]
times = partialdischarges[time_col][pd_occured].apply(datetime.datetime.fromisoformat)

# %%
plt.hist(charges,bins=500)
plt.xlim(0,2e5)
plt.show()

# %%
plt.hist(locations,bins=500)
#plt.xlim(0,2e5)
plt.show()

# %%
plt.scatter(x=locations, y=charges, s=.1, c='.0')
plt.show()

# %%
# %matplotlib notebook
plt.scatter(x=locations, y=times, s=.1, c='.0')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
warning
# Out:
#    Location in meters (m)  SCG warning level (1 to 3 or Noise)  \
# 0                     349                                    3
# 1                     604                                    2
# 2                     604                                    3
#
#   Start Date/time (UTC)  End Date/time (UTC)
# 0   2018-02-26 22:40:58  2018-05-27 08:45:43
# 1   2018-02-05 00:03:25  2018-02-23 16:08:12
# 2   2017-12-30 19:48:43  2018-02-05 00:03:25
