# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
# %config InlineBackend.figure_format = 'retina'

import sys
sys.path.append('..')
import clusterizer

# %load_ext autoreload
# %autoreload 2
# Out:
# Git root path found at: C:\dev\py\SCG-analyse
# Using data path:        C:\dev\py\SCG-analyse\data\origineel

# %%
circuit = clusterizer.circuit.MergedCircuit(2063)
circuit.build()

# %%
clusters = clusterizer.algorithms.clusterize_ensemble(circuit, add=True).get_clusters()

# %%
# Maak een figuur met daarin één Axes-object
fig, ax = plt.subplots(figsize=(8,5))

clusterizer.plot.draw_location_time_scatter(circuit, dot_size_to_charge_ratio=1e3, ax=ax)
clusterizer.plot.overlay_cluster_collection(clusters, ax=ax)
clusterizer.plot.legend_without_duplicate_labels(ax=ax)

# Niet altijd nodig, maar voor dit plotje wil ik alleen het volgende gebied laten zien:
ax.set_xlim(200,800)
ax.set_ylim(np.datetime64("2017-11", "ns"), np.datetime64("2018-05", "ns"))

# Opslaan:
clusterizer.plot.save_figure_for_google_slides("teaserpostzoom")
clusterizer.plot.save_figure_for_latex("teaserpostzoom")
# Out:
# Saved to /notebooks/teaserpostzoom.png
# Saved to /notebooks/teaserpostzoom.pdf
