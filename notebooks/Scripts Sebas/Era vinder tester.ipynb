# %%
import sys
if "..\.." not in sys.path:
    sys.path.append("..\..")
import clusterizer
import datetime

# %%
import matplotlib.pyplot as plt

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Hogere DPI voor plotjes (is mooi)
# %config InlineBackend.figure_format = 'retina'
# Standaard grootte van plotjes in inches
plt.rcParams['figure.figsize'] = [8, 5]

import pandas as pd
import numpy as np

# %%
clusterizer.globals.available_circuits
# Out:
# [2053,
#  2063,
#  2072,
#  2074,
#  2079,
#  2083,
#  2088,
#  2089,
#  2093,
#  2100,
#  2113,
#  2124,
#  2129,
#  2131,
#  2132,
#  2138,
#  2145,
#  2200,
#  2201,
#  2211,
#  2215,
#  2217,
#  2218,
#  2231,
#  2234,
#  2251,
#  2256,
#  2272,
#  226,
#  2290,
#  2294,
#  2295,
#  250,
#  2308,
#  2311,
#  2322,
#  2326,
#  282,
#  286,
#  2346,
#  2347,
#  2352,
#  2354,
#  2362,
#  2363,
#  2368,
#  2369,
#  320,
#  321,
#  2383,
#  2384,
#  338,
#  2387,
#  2388,
#  2393,
#  352,
#  2432,
#  2434,
#  2438,
#  2455,
#  2491,
#  2492,
#  2510,
#  2516,
#  2602,
#  2604,
#  2619,
#  2622,
#  2628,
#  2630,
#  2635,
#  2648,
#  2663,
#  2667,
#  2669,
#  2672,
#  2678,
#  2679,
#  2683,
#  2695,
#  2713,
#  2718,
#  2726,
#  2742,
#  2747,
#  2760,
#  2765,
#  2768,
#  2773,
#  2774,
#  2777,
#  2779,
#  2781,
#  2783,
#  2787,
#  2789,
#  2793,
#  2796,
#  2806,
#  2812,
#  2839,
#  2851,
#  2852,
#  2854,
#  2855,
#  808,
#  813,
#  2870,
#  2875,
#  2880,
#  2882,
#  2888,
# ...

# %%
circ = clusterizer.circuit.MergedCircuit(2063)
circ.build()

# %%
circ.pd_occured.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Location in meters (m), dtype: bool

# %%
clusterizer.plot.draw_location_time_scatter(circ)

# %%
import random
length = len(clusterizer.globals.available_circuits)
circnumb = clusterizer.globals.available_circuits[random.randint(0,length)]
randcirc = clusterizer.circuit.MergedCircuit(circnumb)
randcirc.build()

# %%
# %matplotlib notebook

fig,ax = plt.subplots()
clusterizer.plot.draw_location_time_scatter(randcirc, ax=ax)
ax.set_title("Circuitnumber: {}".format(circnumb))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Circuitnumber: 1361')

# %%
df = circ.pd
df.iloc[0]
len(df)
times = df[df.columns[0]]
gaps = []

for i in range(len(df)-1):
    if(times.iloc[i+1]-times.iloc[i] >= datetime.timedelta(minutes=60)):
        print("between {} and {}".format(times.iloc[i],times.iloc[i+1]))
        gaps.append([times.iloc[i],times.iloc[i+1]])
# Out:
# between 2017-08-24 01:40:00 and 2017-08-24 04:00:00
# between 2017-08-24 04:45:00 and 2017-08-24 06:00:00
# between 2017-08-27 14:49:00 and 2017-08-27 16:00:00
# between 2017-08-28 11:40:00 and 2017-08-28 13:00:00
# between 2017-08-31 09:42:00 and 2017-08-31 11:00:00
# between 2017-09-01 11:38:00 and 2017-09-01 13:00:00
# between 2017-09-11 05:29:00 and 2017-09-11 08:00:00
# between 2017-09-29 07:18:00 and 2017-09-30 00:02:00
# between 2017-10-03 09:02:00 and 2017-10-03 11:34:00
# between 2017-10-03 12:07:00 and 2017-11-07 14:17:00
# between 2017-11-29 02:28:00 and 2017-11-29 04:01:00
# between 2017-12-01 01:28:00 and 2017-12-01 03:00:00
# between 2017-12-12 10:00:00 and 2017-12-12 11:00:00
# between 2018-02-05 14:22:00 and 2018-02-07 12:31:00
# between 2018-06-05 23:30:00 and 2018-06-06 09:00:00
# between 2018-07-03 14:46:00 and 2018-07-03 16:01:00
# between 2018-10-02 15:40:00 and 2018-10-02 18:00:00

# %%
gaps
# Out:
# [[Timestamp('2017-08-24 01:40:00'), Timestamp('2017-08-24 04:00:00')],
#  [Timestamp('2017-08-24 04:45:00'), Timestamp('2017-08-24 06:00:00')],
#  [Timestamp('2017-08-27 14:49:00'), Timestamp('2017-08-27 16:00:00')],
#  [Timestamp('2017-08-28 11:40:00'), Timestamp('2017-08-28 13:00:00')],
#  [Timestamp('2017-08-31 09:42:00'), Timestamp('2017-08-31 11:00:00')],
#  [Timestamp('2017-09-01 11:38:00'), Timestamp('2017-09-01 13:00:00')],
#  [Timestamp('2017-09-11 05:29:00'), Timestamp('2017-09-11 08:00:00')],
#  [Timestamp('2017-09-29 07:18:00'), Timestamp('2017-09-30 00:02:00')],
#  [Timestamp('2017-10-03 09:02:00'), Timestamp('2017-10-03 11:34:00')],
#  [Timestamp('2017-10-03 12:07:00'), Timestamp('2017-11-07 14:17:00')],
#  [Timestamp('2017-11-29 02:28:00'), Timestamp('2017-11-29 04:01:00')],
#  [Timestamp('2017-12-01 01:28:00'), Timestamp('2017-12-01 03:00:00')],
#  [Timestamp('2017-12-12 10:00:00'), Timestamp('2017-12-12 11:00:00')],
# ...

# %%
# %matplotlib notebook

fig,ax = plt.subplots()
clusterizer.plot.draw_location_time_scatter(circ, ax=ax)
ax.set_title("Circuitnumber: {}".format(circ.circuitnr))
for gap in gaps:
    plt.axhspan(gap[0], gap[1])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Funtie voor een grafiek van gemiddelde lading door de tijd
def average_charge(circuit, bin_time=datetime.timedelta(days=1),t_start=None, t_end = None):
    df = circ.pd_occured
    averages = []
    date = circ.pd.columns[0]
    t_start=circ.pd[date].iloc[0]
    print(t_start)
    t_end = circ.pd[date].iloc[-1]
    print(t_end)
    for d in range(t_start,t_end,bin_time):
        print(df.loc[date>i])
        #averages.append(df[])
average_charge(circ)
# Out:
# 2017-08-21 14:39:00
# 2018-11-13 11:28:00
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-fd100492c43d> in <module>
#      11         print(df.loc[date>i])
#      12         #averages.append(df[])
# ---> 13 average_charge(circ)
#      14
#
# <ipython-input-61-fd100492c43d> in average_charge(circuit, bin_time, t_start, t_end)
#       8     t_end = circ.pd[date].iloc[-1]
#       9     print(t_end)
# ---> 10     for d in range(t_start,t_end,bin_time):
#      11         print(df.loc[date>i])
#      12         #averages.append(df[])
#
# TypeError: 'Timestamp' object cannot be interpreted as an integer
